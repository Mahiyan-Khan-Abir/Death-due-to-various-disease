# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahiyan-Khan-Abir/Death-due-to-various-disease/blob/main/Death_due_to_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Diabates/diabetes.csv")
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df1 = pd.DataFrame(df)
df1.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# 3                       False  False    False
# 4                       False  False    False
# ..                        ...    ...      ...
# 763                     False  False    False
# 764                     False  False    False
# 765                     False  False    False
# 766                     False  False    False
# 767                     False  False    False
#
# [768 rows x 9 columns]

# %%
#Correlation
import matplotlib.pyplot as plt
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_61a31_row0_col0, #T_61a31_row1_col1, #T_61a31_row2_col2, #T_61a31_row3_col3, #T_61a31_row4_col4, #T_61a31_row5_col5, #T_61a31_row6_col6, #T_61a31_row7_col7, #T_61a31_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_61a31_row0_col1, #T_61a31_row1_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_61a31_row0_col2, #T_61a31_row2_col0, #T_61a31_row5_col6, #T_61a31_row6_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_61a31_row0_col3, #T_61a31_row3_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_61a31_row0_col4, #T_61a31_row4_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_61a31_row0_col5, #T_61a31_row5_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_61a31_row0_col6, #T_61a31_row6_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_61a31_row0_col7, #T_61a31_row7_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_61a31_row0_col8, #T_61a31_row8_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_61a31_row1_col2, #T_61a31_row2_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_61a31_row1_col3, #T_61a31_row3_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_61a31_row1_col4, #T_61a31_row4_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_61a31_row1_col5, #T_61a31_row5_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_61a31_row1_col6, #T_61a31_row6_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_61a31_row1_col7, #T_61a31_row7_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_61a31_row1_col8, #T_61a31_row8_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_61a31_row2_col3, #T_61a31_row3_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_61a31_row2_col4, #T_61a31_row4_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_61a31_row2_col5, #T_61a31_row5_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_61a31_row2_col6, #T_61a31_row6_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_61a31_row2_col7, #T_61a31_row7_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_61a31_row2_col8, #T_61a31_row8_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_61a31_row3_col4, #T_61a31_row4_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_61a31_row3_col5, #T_61a31_row5_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_61a31_row3_col6, #T_61a31_row4_col6, #T_61a31_row6_col3, #T_61a31_row6_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_61a31_row3_col7, #T_61a31_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_61a31_row3_col8, #T_61a31_row8_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_61a31_row4_col5, #T_61a31_row5_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_61a31_row4_col7, #T_61a31_row7_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_61a31_row4_col8, #T_61a31_row8_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_61a31_row5_col7, #T_61a31_row7_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_61a31_row5_col8, #T_61a31_row8_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_61a31_row6_col7, #T_61a31_row7_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_61a31_row6_col8, #T_61a31_row8_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_61a31_row7_col8, #T_61a31_row8_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# </style>
# <table id="T_61a31_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Pregnancies</th>
#       <th class="col_heading level0 col1" >Glucose</th>
#       <th class="col_heading level0 col2" >BloodPressure</th>
#       <th class="col_heading level0 col3" >SkinThickness</th>
#       <th class="col_heading level0 col4" >Insulin</th>
#       <th class="col_heading level0 col5" >BMI</th>
#       <th class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th class="col_heading level0 col7" >Age</th>
#       <th class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61a31_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_61a31_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_61a31_row0_col1" class="data row0 col1" >0.129459</td>
#       <td id="T_61a31_row0_col2" class="data row0 col2" >0.141282</td>
#       <td id="T_61a31_row0_col3" class="data row0 col3" >-0.081672</td>
#       <td id="T_61a31_row0_col4" class="data row0 col4" >-0.073535</td>
#       <td id="T_61a31_row0_col5" class="data row0 col5" >0.017683</td>
#       <td id="T_61a31_row0_col6" class="data row0 col6" >-0.033523</td>
#       <td id="T_61a31_row0_col7" class="data row0 col7" >0.544341</td>
#       <td id="T_61a31_row0_col8" class="data row0 col8" >0.221898</td>
#     </tr>
#     <tr>
#       <th id="T_61a31_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_61a31_row1_col0" class="data row1 col0" >0.129459</td>
#       <td id="T_61a31_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_61a31_row1_col2" class="data row1 col2" >0.152590</td>
#       <td id="T_61a31_row1_col3" class="data row1 col3" >0.057328</td>
#       <td id="T_61a31_row1_col4" class="data row1 col4" >0.331357</td>
#       <td id="T_61a31_row1_col5" class="data row1 col5" >0.221071</td>
#       <td id="T_61a31_row1_col6" class="data row1 col6" >0.137337</td>
#       <td id="T_61a31_row1_col7" class="data row1 col7" >0.263514</td>
#       <td id="T_61a31_row1_col8" class="data row1 col8" >0.466581</td>
#     </tr>
#     <tr>
#       <th id="T_61a31_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_61a31_row2_col0" class="data row2 col0" >0.141282</td>
#       <td id="T_61a31_row2_col1" class="data row2 col1" >0.152590</td>
#       <td id="T_61a31_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_61a31_row2_col3" class="data row2 col3" >0.207371</td>
#       <td id="T_61a31_row2_col4" class="data row2 col4" >0.088933</td>
#       <td id="T_61a31_row2_col5" class="data row2 col5" >0.281805</td>
#       <td id="T_61a31_row2_col6" class="data row2 col6" >0.041265</td>
#       <td id="T_61a31_row2_col7" class="data row2 col7" >0.239528</td>
#       <td id="T_61a31_row2_col8" class="data row2 col8" >0.065068</td>
#     </tr>
#     <tr>
#       <th id="T_61a31_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_61a31_row3_col0" class="data row3 col0" >-0.081672</td>
#       <td id="T_61a31_row3_col1" class="data row3 col1" >0.057328</td>
#       <td id="T_61a31_row3_col2" class="data row3 col2" >0.207371</td>
#       <td id="T_61a31_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_61a31_row3_col4" class="data row3 col4" >0.436783</td>
#       <td id="T_61a31_row3_col5" class="data row3 col5" >0.392573</td>
#       <td id="T_61a31_row3_col6" class="data row3 col6" >0.183928</td>
#       <td id="T_61a31_row3_col7" class="data row3 col7" >-0.113970</td>
#       <td id="T_61a31_row3_col8" class="data row3 col8" >0.074752</td>
#     </tr>
#     <tr>
#       <th id="T_61a31_level0_row4" class="row_heading level0 row4" >Insulin</th>
#       <td id="T_61a31_row4_col0" class="data row4 col0" >-0.073535</td>
#       <td id="T_61a31_row4_col1" class="data row4 col1" >0.331357</td>
#       <td id="T_61a31_row4_col2" class="data row4 col2" >0.088933</td>
#       <td id="T_61a31_row4_col3" class="data row4 col3" >0.436783</td>
#       <td id="T_61a31_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_61a31_row4_col5" class="data row4 col5" >0.197859</td>
#       <td id="T_61a31_row4_col6" class="data row4 col6" >0.185071</td>
#       <td id="T_61a31_row4_col7" class="data row4 col7" >-0.042163</td>
#       <td id="T_61a31_row4_col8" class="data row4 col8" >0.130548</td>
#     </tr>
#     <tr>
#       <th id="T_61a31_level0_row5" class="row_heading level0 row5" >BMI</th>
#       <td id="T_61a31_row5_col0" class="data row5 col0" >0.017683</td>
#       <td id="T_61a31_row5_col1" class="data row5 col1" >0.

# %%
x= df.iloc[:, [0,1,4,5,6,7]].values  
y= df.iloc[:, 8].values  
print(x)
# Out:
# [[  6.    148.      0.     33.6     0.627  50.   ]
#  [  1.     85.      0.     26.6     0.351  31.   ]
#  [  8.    183.      0.     23.3     0.672  32.   ]
#  ...
#  [  5.    121.    112.     26.2     0.245  30.   ]
#  [  1.    126.      0.     30.1     0.349  47.   ]
#  [  1.     93.      0.     30.4     0.315  23.   ]]

# %% [markdown]
# **Spliting the dataset**

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler    
st_x= StandardScaler()    
x_train= st_x.fit_transform(x_train)    
x_test= st_x.transform(x_test)

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression  
classifier= LogisticRegression(random_state=0)  
classifier.fit(x_train, y_train)  

LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,  
                   intercept_scaling=1, l1_ratio=None, max_iter=100,  
                   multi_class='warn', n_jobs=None, penalty='l2',  
                   random_state=0, solver='warn', tol=0.0001, verbose=0,  
                   warm_start=False)  
y_pred= classifier.predict(x_test)  

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2*100,'%')
# Out:
# Confusion Matrix:
# [[117  13]
#  [ 27  35]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       130
#            1       0.73      0.56      0.64        62
#
#     accuracy                           0.79       192
#    macro avg       0.77      0.73      0.75       192
# weighted avg       0.79      0.79      0.78       192
#
# Accuracy: 79.16666666666666 %

# %% [markdown]
# **K-Neighbors Classifier**

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 8)
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2*100,'%')
# Out:
# Confusion Matrix:
# [[118  12]
#  [ 29  33]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85       130
#            1       0.73      0.53      0.62        62
#
#     accuracy                           0.79       192
#    macro avg       0.77      0.72      0.73       192
# weighted avg       0.78      0.79      0.78       192
#
# Accuracy: 78.64583333333334 %

# %% [markdown]
# **Naïve Bayes**

# %%
# Fitting Naive Bayes to the Training set  
from sklearn.naive_bayes import GaussianNB  
classifier = GaussianNB()  
classifier.fit(x_train, y_train)  

# Predicting the Test set results  
y_pred = classifier.predict(x_test)  
 

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2*100,'%')
# Out:
# Confusion Matrix:
# [[116  14]
#  [ 29  33]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       130
#            1       0.70      0.53      0.61        62
#
#     accuracy                           0.78       192
#    macro avg       0.75      0.71      0.72       192
# weighted avg       0.77      0.78      0.77       192
#
# Accuracy: 77.60416666666666 %

# %% [markdown]
# **SVM**

# %%
from sklearn import datasets
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score
 

skf = StratifiedKFold(n_splits=10)
clf = svm.SVC(kernel='linear', C=1)

X= df.iloc[:, [5]].values  
Y= df.iloc[:, 6].values 
    
    
from sklearn.svm import SVC # "Support vector classifier"  
classifier = SVC(kernel='linear', random_state=0)  
classifier.fit(x_train, y_train)

#Predicting the test set result  
y_pred= classifier.predict(x_test)  

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2*100,'%')
# Out:
# Confusion Matrix:
# [[118  12]
#  [ 27  35]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86       130
#            1       0.74      0.56      0.64        62
#
#     accuracy                           0.80       192
#    macro avg       0.78      0.74      0.75       192
# weighted avg       0.79      0.80      0.79       192
#
# Accuracy: 79.6875 %
